# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Matthew**
#
# Business Intelligence Analyst

# %% [markdown]
# *I am interested in data science because there are so many questions that I have about the world around me that I feel like data could help answer. Oftentimes, people give anecdotal information that is viewed as a fact, but are they an an anomaly or an insight? I feel like with data science this question and others can be tackled.*

# %% [markdown]
# ### The code below is printing out a number as a zero padded string

# %%
print('{0:02d}'.format(9))
# Out:
# 09

# %% [markdown]
# Markdown formatting:
#
# ---
#
# * bullet list
# * bullet list item 2
#
# 1. number list
# 2. number list item 2
#
# | column 1 | column 2|
# |---|---|
# | cell 1 | cell 2|
#
# ~~strikethrough~~
