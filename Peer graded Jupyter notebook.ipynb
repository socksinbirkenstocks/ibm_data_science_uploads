# %% [markdown]
# # Peer Graded Jupyter Notebook

# %% [markdown]
# *Hello, welcome to my peer graded jupyter notebook. I'll be going through each exercise below*

# %% [markdown]
# Data Science Languages:
#
# * Python
# * R
# * Javascript
# * Java

# %% [markdown]
# Data Science Libraries:
#
# * scikit-learn
# * TensorFlow
# * PyTorch
# * Therano

# %% [markdown]
# Data Science Tools:
#
# * MySQL
# * Hadoop
# * Apache Airflow
# * Prometheus

# %% [markdown]
# Evaluating Basic Arithmetic Expression

# %%
(10 + 30) * 5
# Out:
# 200

# %%
# code to convert minutes to hours
def minute_to_hour_converter(number):
    minutes = number
    hours = minutes / 60
    return hours

minute_to_hour_converter(120)
# Out:
# 2.0

# %% [markdown]
# Objectives list:
#
# * Learn more about data science techniques
# * Learn more about data science libraries
# * Learn more about how to explain data science findings in an easy to digest manner

# %% [markdown]
# Author's name: Matthew
